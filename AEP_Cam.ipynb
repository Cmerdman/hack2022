# %%
import pandas as pd
import numpy as np
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import r2_score
#from sklearn import metrics
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt
import plotly.express as px

# %%
dat = pd.read_csv("cleaned/datAClean.csv")
dat = dat.drop("Unnamed: 0", axis=1)

# %%
dat.head()
# Out:
#            Date & Time  (GRID) OPERATING TIME  \
# 0  2021-09-20 00:00:00              -1.738051
# 1  2021-09-20 00:10:00              -1.738051
# 2  2021-09-20 00:20:00              -1.737805
# 3  2021-09-20 00:30:00              -1.737805
# 4  2021-09-20 00:40:00              -1.737559
#
#    (GRID) OPERATING TIME UP TO LAST MONTH  Average Air Density 82m  \
# 0                               -1.862232                -1.986125
# 1                               -1.862232                -1.986125
# 2                               -1.862232                -1.986125
# 3                               -1.862232                -1.986125
# 4                               -1.862232                -1.986125
#
#    AXIS 3 BATTERY CABINET TEMPERATURE  AXIS 1 CONTROL CABINET TEMPERATURE  \
# 0                            1.245600                            1.068043
# 1                            1.242804                            1.065631
# 2                            1.240007                            1.063219
# 3                            1.237211                            1.060807
# 4                            1.159415                            1.058395
#
#    AXIS 2 CONTROL CABINET TEMPERATURE  AXIS 3 CONTROL CABINET TEMPERATURE  \
# 0                            1.071597                            1.093324
# 1                            1.069199                            1.090902
# 2                            1.066801                            1.016375
# 3                            1.064403                            1.015782
# 4                            0.981547                            1.015189
#
#    BLADE 1 - ACTUAL VALUE  BLADE 1 - SET VALUE  ...  WEATHER OUTAGE  \
# 0               -0.613881            -0.625479  ...       -1.262601
# 1               -0.643406            -0.644300  ...       -1.262601
# 2               -0.642631            -0.642973  ...       -1.262601
# 3               -0.644948            -0.646360  ...       -1.262601
# 4               -0.683435            -0.683806  ...       -1.262601
#
#    WEATHER OUTAGE UP TO LAST MONTH  WIND DEVIATION 1 SEC.  \
# 0                        -1.333322               0.053391
# 1                        -1.333322               0.080727
# 2                        -1.333322               0.196059
# 3                        -1.333322               0.019296
# 4                        -1.333322               0.007963
#
#    WIND DEVIATION 10 SEC.  WIND DIRECTION  WIND SPEED  YAW DEVIATION  \
# 0                0.068270       -0.048186    0.726780      -0.553761
# 1                0.113487       -0.008924    0.554224      -0.526673
# 2                0.183960       -0.028555    1.019748      -0.532211
# 3               -0.003477       -0.067817    0.533007      -0.462918
# 4                0.009573       -0.058001    0.394588      -0.454895
#
#    YAW REVOLUTIONS TO UNTWIST  Power Difference  \
# 0                   -0.482655         -0.086067
# 1                   -0.482655         -0.148768
# 2                   -0.482655         -0.112272
# 3                   -0.482655         -0.034373
# 4                   -0.482655         -0.246590
#
#    Power Difference Rolling 5 Day
# 0                       -0.086067
# 1                       -0.148768
# 2                       -0.112272
# 3                       -0.034373
# 4                       -0.246590
#
# [5 rows x 110 columns]
